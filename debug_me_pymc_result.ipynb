# %%
import arviz as az

# %%
import joblib as jb

with open("/workspaces/PK-Analysis/trace_nuts_09042025-061920.jb", 'rb') as f:
    df = jb.load(f)

# %%
az.plot_trace(df)
# Out:
# /opt/poetry-venvs/docker-cuda-env-ZRtGBNB8-py3.13/lib/python3.13/site-packages/arviz/stats/density_utils.py:488: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# array([[<Axes: title={'center': 'cl_pop'}>,
#         <Axes: title={'center': 'cl_pop'}>],
#        [<Axes: title={'center': 'cl_intercept_mu'}>,
#         <Axes: title={'center': 'cl_intercept_mu'}>],
#        [<Axes: title={'center': 'z_cl'}>,
#         <Axes: title={'center': 'z_cl'}>],
#        [<Axes: title={'center': 'vd_pop'}>,
#         <Axes: title={'center': 'vd_pop'}>],
#        [<Axes: title={'center': 'cl_intercept_sigma'}>,
#         <Axes: title={'center': 'cl_intercept_sigma'}>],
#        [<Axes: title={'center': 'sigma_obs'}>,
#         <Axes: title={'center': 'sigma_obs'}>],
#        [<Axes: title={'center': 'cl_intercept'}>,
#         <Axes: title={'center': 'cl_intercept'}>],
# ...

# %%
az.summary(df)
# Out:
# /opt/poetry-venvs/docker-cuda-env-ZRtGBNB8-py3.13/lib/python3.13/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /opt/poetry-venvs/docker-cuda-env-ZRtGBNB8-py3.13/lib/python3.13/site-packages/arviz/stats/diagnostics.py:991: RuntimeWarning: invalid value encountered in scalar divide
#   varsd = varvar / evar / 4
# /opt/poetry-venvs/docker-cuda-env-ZRtGBNB8-py3.13/lib/python3.13/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /opt/poetry-venvs/docker-cuda-env-ZRtGBNB8-py3.13/lib/python3.13/site-packages/arviz/stats/diagnostics.py:991: RuntimeWarning: invalid value encountered in scalar divide
#   varsd = varvar / evar / 4
# ...
