# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from utils import plot_subject_levels

# %%
df = pd.read_csv(r'/workspaces/miniconda/PKdata/data-raw/KI20160914/KI20160914.csv')

# %%
plot_subject_levels(df)

# %%
from scipy.integrate import solve_ivp
import numpy as np
from tqdm import tqdm
from utils import one_compartment_model, objective_function

# %%
#prepare day 1 data
opt_df = df.dropna(subset = 'DV').copy()
opt_df['DV'] = opt_df['DV'].astype(pd.Float32Dtype())
opt_df = opt_df.loc[opt_df['DAY'] == 1, :]

#Within day 1 data, per subject identify the max concentration
#Drop time points occuring before the max, and set the time at that max conc to t=0
dfs = []
for c in opt_df['SUBJID'].drop_duplicates():
    work_df = opt_df.loc[opt_df['SUBJID'] == c, :].reset_index(drop = True)
    max_idx = work_df.loc[work_df['DV'] == work_df['DV'].max(), :].index[0]
    work_df = work_df.iloc[max_idx:, :]
    work_df['TIME'] = work_df['TIME'] - work_df['TIME'].min()
    dfs.append(work_df.copy())
work_df = pd.concat(dfs)

# %%
#plot the prepared data
plot_subject_levels(work_df)

# %%
import numpy as np
from scipy.optimize import minimize
from joblib import dump, load
import os
from functools import partial
from utils import optimize_with_checkpoint_joblib

# %%
from sklearn.preprocessing import RobustScaler
scale_df = work_df.copy()
#scale_df[['DV']] = RobustScaler().fit_transform(scale_df[['DV']])
mgkg_scaler = RobustScaler()
age_scaler = RobustScaler()
wt_scaler = RobustScaler()

scale_df['MGKG'] = (scale_df['DOSR'] / scale_df['WT'])
scale_df['WT_scale'] = wt_scaler.fit_transform(scale_df[['WT']])
scale_df['MGKG_scale'] = mgkg_scaler.fit_transform(scale_df[['MGKG']])
scale_df['AGE_scale'] = age_scaler.fit_transform(scale_df[['AGE']])
scale_df['DOSR'] = scale_df['DOSR'] / 100
plot_subject_levels(scale_df)

# %%
scale_df
# Out:
#     SUBJID  VIST  DAY  TIME  NTPD  DOSR  AMT     DV  FORM TRTCD  SEX   AGE  \
# 2      1.0   1.0  1.0   0.0   1.0   3.0  NaN  275.0   0.0     B  1.0  26.0
# 3      1.0   1.0  1.0   1.0   2.0   3.0  NaN  244.0   0.0     B  1.0  26.0
# 4      1.0   1.0  1.0   2.0   3.0   3.0  NaN  151.0   0.0     B  1.0  26.0
# 5      1.0   1.0  1.0   3.0   4.0   3.0  NaN  130.0   0.0     B  1.0  26.0
# 6      1.0   1.0  1.0   5.0   6.0   3.0  NaN  147.0   0.0     B  1.0  26.0
# ..     ...   ...  ...   ...   ...   ...  ...    ...   ...   ...  ...   ...
# 10   159.0   1.0  1.0  21.0  24.0   1.0  NaN   7.91   1.0     B  1.0  33.0
# 11   159.0   1.0  1.0  33.0  36.0   1.0  NaN   3.02   1.0     B  1.0  33.0
# 12   159.0   1.0  1.0  45.0  48.0   1.0  NaN    1.7   1.0     B  1.0  33.0
# 13   159.0   1.0  1.0  69.0  72.0   1.0  NaN   1.42   1.0     B  1.0  33.0
# 14   159.0   1.0  1.0  93.0  96.0   1.0  NaN  0.851   1.0     B  1.0  33.0
#
#       WT      MGKG  WT_scale  MGKG_scale  AGE_scale
# 2   84.0  3.571429    0.3125    0.248950   0.071429
# 3   84.0  3.571429    0.3125    0.248950   0.071429
# 4   84.0  3.571429    0.3125    0.248950   0.071429
# 5   84.0  3.571429    0.3125    0.248950   0.071429
# 6   84.0  3.571429    0.3125    0.248950   0.071429
# ..   ...       ...       ...         ...        ...
# 10  95.0  1.052632    1.0000   -0.745975   0.571429
# 11  95.0  1.052632    1.0000   -0.745975   0.571429
# 12  95.0  1.052632    1.0000   -0.745975   0.571429
# 13  95.0  1.052632    1.0000   -0.745975   0.571429
# 14  95.0  1.052632    1.0000   -0.745975   0.571429
#
# [1620 rows x 17 columns]

# %% [markdown]
# # Just Optimizing the ODE

# %%
from scipy.optimize import minimize

run_ode_only = False
if run_ode_only:
# opt_df = opt_df.loc[opt_df['TIME'] >= 1, :].copy()
    initial_guess = [0.6, 2.0]  # Initial guesses for k and Vd
    result_0 = optimize_with_checkpoint_joblib(objective_function, initial_guess, n_checkpoint=5, checkpoint_filename='check.jb', args=(
        # Bounds added to prevent negative values
        scale_df,), bounds=[(1e-6, None), (1e-6, None)])
    # result = minimize(objective_function, initial_guess, args=(work_df,), bounds=[(1e-6,None),(1e-6,None)])

# %% [markdown]
# result_0

# %% [markdown]
# # With Covariates

# %%
from utils import ObjectiveFunctionColumn

# %%
from utils import arbitrary_objective_function
import warnings
import joblib as jb

run_test_mod = False
if run_test_mod:
    warnings.filterwarnings("error", category= RuntimeWarning)

    initial_guess = [np.log(0.6), np.log(2.0), 0, 0, 0 ] 
    objective_func_arbit_allometric = partial(arbitrary_objective_function,
                                dep_vars = {'k':[ ObjectiveFunctionColumn('AGE_scale'),
                                                    ObjectiveFunctionColumn('SEX')],
                                            'vd':[ObjectiveFunctionColumn('WT_scale',
                                                                            model_method='allometric', 
                                                                            allometric_norm_value=wt_scaler.transform([[70]])[0][0]
                                                                            )]})
    result_arbit_allo = optimize_with_checkpoint_joblib(objective_func_arbit_allometric, initial_guess, n_checkpoint=5, checkpoint_filename='check_args_arbit_al.jb', args=(
        # Bounds added to prevent negative values
        scale_df,), bounds=[(None, None), (None, None), (None, None), (None, None), (None, None),])

    with open('result_arbit_allo.jb', 'wb') as f:
        jb.dump(result_arbit_allo, f)
else:
    with open('result_arbit_allo.jb', 'rb') as f:
        result_arbit_allo = jb.load(f)

# %%
result_arbit_allo
# Out:
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 1815086.6522424195
#         x: [-9.810e-01  2.429e-02 -2.122e-01 -5.101e-01  4.790e-01]
#       nit: 4
#       jac: [ 4.695e+05 -3.533e+05 -4.066e+05  3.217e+05 -7.708e+03]
#      nfev: 84
#      njev: 14
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>

# %%
from utils import OneCompartmentModel

# %%
from utils import sum_of_squares_loss
import cProfile

mod_sse = OneCompartmentModel(dep_vars= {'k':[ ObjectiveFunctionColumn('AGE_scale'),
                                                ObjectiveFunctionColumn('SEX' )],
                                           'vd':[ObjectiveFunctionColumn('WT_scale',
                                                                         model_method='linear',
                                                                         
                                                                         allometric_norm_value=wt_scaler.transform([[70]])[0][0], 
                                                                         
                                                                         )]}, 
                              loss_function=sum_of_squares_loss, 
                              optimizer_tol=None
                              )
# Out:
# /opt/conda/envs/pySunODE/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RobustScaler was fitted with feature names
#   warnings.warn(

# %%
mod_sse.init_vals_pd
# Out:
#   model_coeff model_coeff_dep_var  population_coeff  init_val  allometric  \
# 0           k                None              True -0.510826       False
# 1          vd                None              True  0.693147       False
# 2           k           AGE_scale             False  0.000000       False
# 3           k                 SEX             False  0.000000       False
# 4          vd            WT_scale             False  0.000000       False
#
#    allometric_norm_value
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                -0.5625

# %%
mod_sse_pymc = mod_sse.fit_pymc(scale_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a real number, not 'TensorVariable'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 mod_sse_pymc = mod_sse.fit_pymc(scale_df)
#
# File /workspaces/miniconda/PK-Analysis/utils.py:306, in OneCompartmentModel.fit_pymc(self, data, **kwargs)
#     305 def fit_pymc(self, data, **kwargs):
# --> 306     model = self._pymc_model(data)
#     307     with model:
#     308         self.trace_ = pm.sample(**kwargs)  # Perform sampling
#
# File /workspaces/miniconda/PK-Analysis/utils.py:292, in OneCompartmentModel._pymc_model(self, data)
#     289 subject_data = data[data[self.groupby_col] == subject]
#     290 initial_conc = subject_data[self.conc_at_time_col].values[0]
# --> 292 sol = solve_ivp(self.pk_model_function,
#     293                 [subject_data[self.time_col].min(), subject_data[self.time_col].max()],
#     294                 [initial_conc],
#     295                 t_eval=subject_data[self.time_col],
#     296                 args=(subject_params[subject]['k'], subject_params[subject]['vd'], 1))
#     298 y_pred_subject = pm.Normal("y_pred_subject", mu=sol.y[0], sigma=0.1, observed=subject_data[self.conc_at_time_col])
#     299 y_pred.append(y_pred_subject)
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/integrate/_ivp/ivp.py:621, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     618 if method in METHODS:
#     619     method = METHODS[method]
# --> 621 solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     623 if t_eval is None:
#     624     ts = [t0]
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/integrate/_ivp/rk.py:94, in RungeKutta.__init__(self, fun, t0, y0, t_bound, max_step, rtol, atol, vectorized, first_step, **extraneous)
#      92 self.max_step = validate_max_step(max_step)
#      93 self.rtol, self.atol = validate_tol(rtol, atol, self.n)
# ---> 94 self.f = self.fun(self.t, self.y)
#      95 if first_step is None:
#      96     self.h_abs = select_initial_step(
#      97         self.fun, self.t, self.y, t_bound, max_step, self.f, self.direction,
#      98         self.error_estimator_order, self.rtol, self.atol)
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/integrate/_ivp/base.py:154, in OdeSolver.__init__.<locals>.fun(t, y)
#     152 def fun(t, y):
#     153     self.nfev += 1
# --> 154     return self.fun_single(t, y)
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/integrate/_ivp/base.py:23, in check_arguments.<locals>.fun_wrapped(t, y)
#      22 def fun_wrapped(t, y):
# ---> 23     return np.asarray(fun(t, y), dtype=dtype)
#
# ValueError: setting an array element with a sequence.

# %%
import cProfile
import pstats

#profiler = cProfile.Profile()
#profiler.enable()

mod_sse = mod_sse.fit(scale_df, parallel=True, warm_start=False, checkpoint_filename='check_allo_sse.jb')

#profiler.disable()
#stats = pstats.Stats(profiler).sort_stats('cumtime') # 'cumtime' for total time in a function
# Out:
# Iteration 5: Checkpoint saved to logs/check_allo_sse__5.jb
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 7
#       2 import pstats
#       4 #profiler = cProfile.Profile()
#       5 #profiler.enable()
# ----> 7 mod_sse = mod_sse.fit(scale_df, parallel=True, warm_start=False, checkpoint_filename='check_allo_sse.jb')
#       9 #profiler.disable()
#      10 #stats = pstats.Stats(profiler).sort_stats('cumtime') # 'cumtime' for total time in a function
#
# File /workspaces/miniconda/PK-Analysis/utils.py:386, in OneCompartmentModel.fit(self, data, parallel, parallel_n_jobs, warm_start, checkpoint_filename)
#     383 def fit(self, data, parallel = False, parallel_n_jobs = -1 , warm_start = False, checkpoint_filename='check_test.jb'):
#     384     # bounds = [(None, None) for i in range(len(self.dep_vars) + len(self.population_coeff))]
#     385     objective_function = partial(self._objective_function, parallel = parallel, parallel_n_jobs = parallel_n_jobs)
# --> 386     self.fit_result_ = optimize_with_checkpoint_joblib(objective_function,
#     387                                                        self.init_vals,
#     388                                                        n_checkpoint=5,
#     389                                                        checkpoint_filename=checkpoint_filename,
#     390                                                        args=(data,),
#     391                                                        warm_start=warm_start,
#     392                                                        tol = self.optimzer_tol,
#     393                                                        bounds=self.bounds
#     394                                                        )
#     395     res_df = []
#     396     written_indep_var_rows = 0
#
# File /workspaces/miniconda/PK-Analysis/utils.py:679, in optimize_with_checkpoint_joblib(func, x0, n_checkpoint, checkpoint_filename, warm_start, tol, *args, **kwargs)
#     675         user_callback(xk)
#     677     kwargs['callback'] = combined_callback
# --> 679 result = minimize(func, x0, *args, tol = tol, **kwargs)
#     681 # Remove checkpoint file at end.
#     682 # try:
#     683 #    os.remove(checkpoint_filename)
#     684 # except:
#     685 #    pass
#     687 return result
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_minimize.py:731, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     728     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     729                              **options)
#     730 elif meth == 'l-bfgs-b':
# --> 731     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     732                            callback=callback, **options)
#     733 elif meth == 'tnc':
#     734     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     735                         **options)
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_lbfgsb_py.py:407, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     401 task_str = task.tobytes()
#     402 if task_str.startswith(b'FG'):
#     403     # The minimization routine wants f and g at the current x.
#     404     # Note that interruptions due to maxfun are postponed
#     405     # until the completion of the current minimization iteration.
#     406     # Overwrite f and g:
# --> 407     f, g = func_and_grad(x)
#     408 elif task_str.startswith(b'NEW_X'):
#     409     # new iteration
#     410     n_iterations += 1
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:344, in ScalarFunction.fun_and_grad(self, x)
#     342     self._update_x(x)
#     343 self._update_fun()
# --> 344 self._update_grad()
#     345 return self.f, self.g
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:306, in ScalarFunction._update_grad(self)
#     304 if self._orig_grad in FD_METHODS:
#     305     self._update_fun()
# --> 306 self.g = self._wrapped_grad(self.x, f0=self.f)
#     307 self.g_updated = True
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:47, in _wrapper_grad.<locals>.wrapped1(x, f0)
#      45 def wrapped1(x, f0=None):
#      46     ncalls[0] += 1
# ---> 47     return approx_derivative(
#      48         fun, x, f0=f0, **finite_diff_options
#      49     )
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:592, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     590     x1[i] += h[i]
#     591     dx = x1[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 592     df = fun(x1) - f0
#     593 elif method == '3-point' and use_one_sided[i]:
#     594     x1[i] += h[i]
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:20, in _wrapper_fun.<locals>.wrapped(x)
#      16 ncalls[0] += 1
#      17 # Send a copy because the user may overwrite it.
#      18 # Overwriting results in undefined behaviour because
#      19 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 20 fx = fun(np.copy(x), *args)
#      21 # Make sure the function returns a true scalar
#      22 if not np.isscalar(fx):
#
# File /workspaces/miniconda/PK-Analysis/utils.py:377, in OneCompartmentModel._objective_function(self, params, data, parallel, parallel_n_jobs)
#     375 _betas = self._populate_model_betas(other_params)
#     376 #preds = np.concatenate(self._predict_parallel(data = data)) if parallel else self._predict_alt(data=data)
# --> 377 preds = self.predict(data, parallel = parallel, parallel_n_jobs = parallel_n_jobs)
#     378 #residuals = data[self.conc_at_time_col] - preds
#     379 #sse = np.sum(residuals**2)
#     380 error = self.loss_function(data[self.conc_at_time_col], preds, **self.loss_params)
#
# File /workspaces/miniconda/PK-Analysis/utils.py:360, in OneCompartmentModel.predict(self, data, parallel, parallel_n_jobs, return_df)
#     358 def predict(self, data, parallel = True, parallel_n_jobs = -1, return_df=False):
#     359     if parallel:
# --> 360         predictions = self._predict_parallel(data, parallel_n_jobs=parallel_n_jobs)
#     361     else:
#     362         predictions = self._predict_alt(data)
#
# File /workspaces/miniconda/PK-Analysis/utils.py:345, in OneCompartmentModel._predict_parallel(self, data, parallel_n_jobs)
#     344 def _predict_parallel(self, data, parallel_n_jobs = -1):
# --> 345     predictions = Parallel(n_jobs=parallel_n_jobs)(delayed(self._predict_inner)(data_out) for data_out in self._subject_iterator(data))
#     346     return np.concatenate(predictions)
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/joblib/parallel.py:1768, in Parallel._retrieve(self)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
# -> 1768 with self._lock:
#    1769     batched_results = self._jobs.popleft()
#    1771 # Flatten the batched results to output one output at a time
#
# KeyboardInterrupt:

# %%
sse_df = mod_sse.predict(scale_df, return_df=True)

# %%
mod_sse.fit_result_
# Out:
#   message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#   success: True
#    status: 0
#       fun: 6601234.5
#         x: [-5.108e-01  6.931e-01  0.000e+00  0.000e+00  0.000e+00]
#       nit: 0
#       jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#      nfev: 6
#      njev: 1
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>

# %%
mod_sse.fit_result_summary_
# Out:
#    population_coeff model_coeff model_coeff_indep_var  log_coeff  \
# 0              True           k                  None  -0.510826
# 1              True          vd                  None   0.693147
# 2             False           k             AGE_scale   0.000000
# 3             False           k                   SEX   0.000000
# 4             False          vd              WT_scale   0.000000
#
#    log_coeff_history_final  coeff_estimates_equal  coeff
# 0            -5.108256e-01                   True    0.6
# 1             6.931472e-01                   True    2.0
# 2             0.000000e+00                   True    1.0
# 3             0.000000e+00                   True    1.0
# 4             1.000000e-08                  False    1.0

# %%
from utils import OneCompartmentModel, mean_squared_error_loss


mod_mse = OneCompartmentModel(dep_vars= {'k':[ ObjectiveFunctionColumn('AGE_scale'),
                                                ObjectiveFunctionColumn('SEX')],
                                           'vd':[ObjectiveFunctionColumn('WT_scale',
                                                                         model_method='linear', 
                                                                         #allometric_norm_value=wt_scaler.transform([[70]])[0][0]
                                                                         )]}, 
                          loss_function=mean_squared_error_loss
                          )
mod_mse = mod_mse.fit(scale_df, parallel=True, checkpoint_filename='check_allo_mse.jb')

# %%
mod_mse.fit_result_
# Out:
#   message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#   success: True
#    status: 0
#       fun: 1386.0636
#         x: [-5.108e-01  6.931e-01  0.000e+00  0.000e+00  0.000e+00]
#       nit: 0
#       jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#      nfev: 6
#      njev: 1
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>

# %%
rse_df = mod_mse.predict(scale_df, return_df=True)

# %%
from utils import huber_loss

mod_huber = OneCompartmentModel(dep_vars= {'k':[ ObjectiveFunctionColumn('AGE_scale'),
                                                ObjectiveFunctionColumn('SEX')],
                                           'vd':[ObjectiveFunctionColumn('WT_scale',
                                                                         model_method='linear', 
                                                                         
                                                                         )]}, 
                          loss_function=huber_loss,
                          loss_params={'delta':1.73}, 
                          optimizer_tol=1e-5
                          )
mod_huber = mod_huber.fit(scale_df, parallel=True, parallel_n_jobs=3)
# Out:
# Iteration 5: Checkpoint saved to logs/check_test__5.jb
# Iteration 10: Checkpoint saved to logs/check_test__10.jb

# %%
mod_huber.fit_result_summary_
# Out:
#    population_coeff model_coeff model_coeff_indep_var  log_coeff  \
# 0              True           k                  None  -0.514065
# 1              True          vd                  None   0.696386
# 2             False           k             AGE_scale  -0.090781
# 3             False           k                   SEX  -0.397012
# 4             False          vd              WT_scale  -0.076311
#
#    log_coeff_history_final  coeff_estimates_equal     coeff
# 0                -0.514065                   True  0.598060
# 1                 0.696386                   True  2.006488
# 2                -0.090781                   True  0.913217
# 3                -0.397012                   True  0.672326
# 4                -0.076311                  False  0.926528

# %%
mod_huber.fit_result_summary_
# Out:
#    population_coeff model_coeff model_coeff_indep_var  log_coeff  \
# 0              True           k                  None  -0.634708
# 1              True          vd                  None   0.817030
# 2             False           k             AGE_scale  -0.034198
# 3             False           k                   SEX  -0.140495
# 4             False          vd              WT_scale   0.001791
#
#    log_coeff_history_final  coeff_estimates_equal     coeff
# 0                -0.634708                   True  0.530090
# 1                 0.817030                   True  2.263766
# 2                -0.034198                   True  0.966380
# 3                -0.140495                   True  0.868928
# 4                 0.001791                  False  1.001793

# %%
huber_df = mod_huber.predict(scale_df, return_df=True)

# %%
from sklearn.model_selection import GroupKFold
from utils import OneCompartmentModel
huber_deltas = np.linspace(1.25,1.9, 30)
#best_delta = 1.7655
best_delta = 1.723
tols = np.linspace(1e-2,1e-10, 100 )
cv_df = scale_df.copy().reset_index(drop = True)
X = cv_df.drop(columns = 'DV').copy()
y = cv_df['DV'].copy()
groups = cv_df['SUBJID'].copy()
allo_scaler = wt_scaler.transform([[70]])[0][0]
# Out:
# /opt/conda/envs/pySunODE/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RobustScaler was fitted with feature names
#   warnings.warn(

# %%
import warnings
from tqdm import tqdm
from utils import huber_loss
import joblib as jb

g_kfold = GroupKFold(n_splits=10, shuffle = True, random_state=42)
g_kfold.get_n_splits(X, y, groups)
fit_parallel = True






res = []
for idx, d in enumerate(tqdm(tols)):
    cv_error = []
    train_idx_history = []
    test_idx_history = [] 
    for i, (train_index, test_index) in enumerate(g_kfold.split(X, y, groups)):
        
        train_X = cv_df.iloc[train_index, :].copy()
        test_X = cv_df.iloc[test_index, :].copy()  

        mod_huber = OneCompartmentModel(dep_vars= {'k':[ ObjectiveFunctionColumn('AGE_scale', ),
                                                    ObjectiveFunctionColumn('SEX') ],
                                            'vd':[ObjectiveFunctionColumn('WT_scale',
                                                                            model_method='linear', 
                                                                            
                                                                            
                                                                            )]}, 
                            loss_function=huber_loss,
                            loss_params={'delta':best_delta}, 
                            optimizer_tol=d
                            )
        mod_huber = mod_huber.fit(train_X, parallel=fit_parallel,parallel_n_jobs=4 ,checkpoint_filename=f'huber_opt_d{d}_cv{i}.jb')
        test_preds = mod_huber.predict(test_X, parallel=fit_parallel,parallel_n_jobs=4 )
        inner_mad = np.mean(np.abs(test_preds - test_X['DV'].values))
        cv_error.append(inner_mad)

        train_idx_history.append(train_index)
        test_idx_history.append(test_index)
    res.append(
        {
            'd':d, 
            'train_idx':train_idx_history, 
            'test_idx':test_idx_history,
            'cv_error':cv_error,
            'avg_cv_error':np.mean(cv_error) if all((i is not None for i in cv_error)) else None
        }
    )
    
    res_df = pd.DataFrame(res)
    with open('cv_log_tol.jb', 'wb') as f:
        jb.dump(res_df, f)
res_df = pd.DataFrame(res)
# Out:
#  33%|███▎      | 33/100 [49:33<1:40:36, 90.09s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 36
#      23 test_X = cv_df.iloc[test_index, :].copy()
#      25 mod_huber = OneCompartmentModel(dep_vars= {'k':[ ObjectiveFunctionColumn('AGE_scale', ),
#      26                                             ObjectiveFunctionColumn('SEX') ],
#      27                                     'vd':[ObjectiveFunctionColumn('WT_scale',
#    (...)
#      34                     optimizer_tol=d
#      35                     )
# ---> 36 mod_huber = mod_huber.fit(train_X, parallel=fit_parallel,parallel_n_jobs=4 ,checkpoint_filename=f'huber_opt_d{d}_cv{i}.jb')
#      37 test_preds = mod_huber.predict(test_X, parallel=fit_parallel,parallel_n_jobs=4 )
#      38 inner_mad = np.mean(np.abs(test_preds - test_X['DV'].values))
#
# File /workspaces/miniconda/PK-Analysis/utils.py:386, in OneCompartmentModel.fit(self, data, parallel, parallel_n_jobs, warm_start, checkpoint_filename)
#     383 def fit(self, data, parallel = False, parallel_n_jobs = -1 , warm_start = False, checkpoint_filename='check_test.jb'):
#     384     # bounds = [(None, None) for i in range(len(self.dep_vars) + len(self.population_coeff))]
#     385     objective_function = partial(self._objective_function, parallel = parallel, parallel_n_jobs = parallel_n_jobs)
# --> 386     self.fit_result_ = optimize_with_checkpoint_joblib(objective_function,
#     387                                                        self.init_vals,
#     388                                                        n_checkpoint=5,
#     389                                                        checkpoint_filename=checkpoint_filename,
#     390                                                        args=(data,),
#     391                                                        warm_start=warm_start,
#     392                                                        tol = self.optimzer_tol,
#     393                                                        bounds=self.bounds
#     394                                                        )
#     395     res_df = []
#     396     written_indep_var_rows = 0
#
# File /workspaces/miniconda/PK-Analysis/utils.py:679, in optimize_with_checkpoint_joblib(func, x0, n_checkpoint, checkpoint_filename, warm_start, tol, *args, **kwargs)
#     675         user_callback(xk)
#     677     kwargs['callback'] = combined_callback
# --> 679 result = minimize(func, x0, *args, tol = tol, **kwargs)
#     681 # Remove checkpoint file at end.
#     682 # try:
#     683 #    os.remove(checkpoint_filename)
#     684 # except:
#     685 #    pass
#     687 return result
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_minimize.py:731, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     728     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     729                              **options)
#     730 elif meth == 'l-bfgs-b':
# --> 731     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     732                            callback=callback, **options)
#     733 elif meth == 'tnc':
#     734     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     735                         **options)
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_lbfgsb_py.py:407, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     401 task_str = task.tobytes()
#     402 if task_str.startswith(b'FG'):
#     403     # The minimization routine wants f and g at the current x.
#     404     # Note that interruptions due to maxfun are postponed
#     405     # until the completion of the current minimization iteration.
#     406     # Overwrite f and g:
# --> 407     f, g = func_and_grad(x)
#     408 elif task_str.startswith(b'NEW_X'):
#     409     # new iteration
#     410     n_iterations += 1
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:344, in ScalarFunction.fun_and_grad(self, x)
#     342     self._update_x(x)
#     343 self._update_fun()
# --> 344 self._update_grad()
#     345 return self.f, self.g
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:306, in ScalarFunction._update_grad(self)
#     304 if self._orig_grad in FD_METHODS:
#     305     self._update_fun()
# --> 306 self.g = self._wrapped_grad(self.x, f0=self.f)
#     307 self.g_updated = True
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:47, in _wrapper_grad.<locals>.wrapped1(x, f0)
#      45 def wrapped1(x, f0=None):
#      46     ncalls[0] += 1
# ---> 47     return approx_derivative(
#      48         fun, x, f0=f0, **finite_diff_options
#      49     )
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:592, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     590     x1[i] += h[i]
#     591     dx = x1[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 592     df = fun(x1) - f0
#     593 elif method == '3-point' and use_one_sided[i]:
#     594     x1[i] += h[i]
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:20, in _wrapper_fun.<locals>.wrapped(x)
#      16 ncalls[0] += 1
#      17 # Send a copy because the user may overwrite it.
#      18 # Overwriting results in undefined behaviour because
#      19 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 20 fx = fun(np.copy(x), *args)
#      21 # Make sure the function returns a true scalar
#      22 if not np.isscalar(fx):
#
# File /workspaces/miniconda/PK-Analysis/utils.py:377, in OneCompartmentModel._objective_function(self, params, data, parallel, parallel_n_jobs)
#     375 _betas = self._populate_model_betas(other_params)
#     376 #preds = np.concatenate(self._predict_parallel(data = data)) if parallel else self._predict_alt(data=data)
# --> 377 preds = self.predict(data, parallel = parallel, parallel_n_jobs = parallel_n_jobs)
#     378 #residuals = data[self.conc_at_time_col] - preds
#     379 #sse = np.sum(residuals**2)
#     380 error = self.loss_function(data[self.conc_at_time_col], preds, **self.loss_params)
#
# File /workspaces/miniconda/PK-Analysis/utils.py:360, in OneCompartmentModel.predict(self, data, parallel, parallel_n_jobs, return_df)
#     358 def predict(self, data, parallel = True, parallel_n_jobs = -1, return_df=False):
#     359     if parallel:
# --> 360         predictions = self._predict_parallel(data, parallel_n_jobs=parallel_n_jobs)
#     361     else:
#     362         predictions = self._predict_alt(data)
#
# File /workspaces/miniconda/PK-Analysis/utils.py:345, in OneCompartmentModel._predict_parallel(self, data, parallel_n_jobs)
#     344 def _predict_parallel(self, data, parallel_n_jobs = -1):
# --> 345     predictions = Parallel(n_jobs=parallel_n_jobs)(delayed(self._predict_inner)(data_out) for data_out in self._subject_iterator(data))
#     346     return np.concatenate(predictions)
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/joblib/parallel.py:1768, in Parallel._retrieve(self)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
# -> 1768 with self._lock:
#    1769     batched_results = self._jobs.popleft()
#    1771 # Flatten the batched results to output one output at a time
#
# KeyboardInterrupt:

# %%
import joblib as jb
debug_X = cv_df.iloc[debug_idx, :].copy()
debug_X_test = cv_df.iloc[debug_test_idx, :].copy()

with open('debug_X.jb', 'wb') as f:
    jb.dump(debug_X, f)
with open('debug_X_test.jb', 'wb') as f:
    jb.dump(debug_X_test, f)

# %%
import joblib as jb
from utils import OneCompartmentModel, huber_loss

with open('debug_X.jb', 'rb') as f:
    debug_X = jb.load(f)

# %%
mod_huber = OneCompartmentModel(dep_vars= {'k':[ ObjectiveFunctionColumn('AGE_scale'),
                                            ObjectiveFunctionColumn('SEX')],
                                    'vd':[ObjectiveFunctionColumn('WT_scale',
                                                                    model_method='linear', 
                                                                    #allometric_norm_value=allo_scaler
                                                                    )]}, 
                    loss_function=huber_loss,
                    loss_params={'delta':best_delta}, 
                    optimizer_tol=1e-3
                    )
mod_huber = mod_huber.fit(scale_df, parallel=True,parallel_n_jobs=4 ,checkpoint_filename=f'huber_opt_debug.jb')

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(1)
plot_df = rse_df.loc[rse_df['SUBJID'] == 5, :]
global_mad = np.mean(np.abs(rse_df['DV'] - rse_df['pred_y']))
mad = np.mean(np.abs(plot_df['DV'] - plot_df['pred_y']))
axs.plot(plot_df['TIME'], plot_df['DV'])
axs.plot(plot_df['TIME'], plot_df['pred_y'], label = f'MSE Opt: SubMAD = {np.round(mad, 2)}, TotalMAD:{np.round(global_mad, 2)}' )

plot_df = sse_df.loc[sse_df['SUBJID'] == 5, :]
global_mad = np.mean(np.abs(sse_df['DV'] - sse_df['pred_y']))
mad = np.mean(np.abs(plot_df['DV'] - plot_df['pred_y']))
#axs[0].plot(plot_df['TIME'], plot_df['DV'])
axs.plot(plot_df['TIME'], plot_df['pred_y'], label = f'SSE Opt: SubMAD = {np.round(mad, 2)}, TotalMAD:{np.round(global_mad, 2)}')

plot_df = huber_df.loc[huber_df['SUBJID'] == 5, :]
global_mad = np.mean(np.abs(huber_df['DV'] - huber_df['pred_y']))
mad = np.mean(np.abs(plot_df['DV'] - plot_df['pred_y']))
#axs[0].plot(plot_df['TIME'], plot_df['DV'])
axs.plot(plot_df['TIME'], plot_df['pred_y'], label = f'Huber Opt: SubMAD = {np.round(mad, 2)}, TotalMAD:{np.round(global_mad, 2)}')
plt.legend()

# %%
from sklearn.

# %%
mod_lin_mse = OneCompartmentModel(dep_vars= {'k':[ ObjectiveFunctionColumn('AGE_scale'),
                                                ObjectiveFunctionColumn('SEX')],
                                           'vd':[ObjectiveFunctionColumn('WT_scale',)]})
mod_lin_mse = mod_lin_mse.fit(scale_df)
# Out:
# No checkpoint found, starting from initial guess.
# 1
# no log
# 2
# no log
# 3
# no log
# 4
# no log
# 5
# Iteration 5: Checkpoint saved to check_test_5.jb
# no log

# %%
mod_lin_mse.fit_result_
# Out:
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 1117.8093170102954
#         x: [-5.936e-01  8.015e-01 -4.243e-02 -8.184e-02  1.066e-02]
#       nit: 5
#       jac: [ 4.338e+02  6.055e+02  5.694e+02  4.067e+02 -1.042e+01]
#      nfev: 228
#      njev: 38
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>

# %%
mod_lin_sse = OneCompartmentModel(dep_vars= {'k':[ ObjectiveFunctionColumn('AGE_scale'),
                                                ObjectiveFunctionColumn('SEX')],
                                           'vd':[ObjectiveFunctionColumn('WT_scale',)]},
                                  loss_function=sum_of_squares_loss
                                  )
mod_lin_sse = mod_lin_sse.fit(scale_df)
# Out:
# No checkpoint found, starting from initial guess.
# 1
# no log
# 2
# no log
# 3
# no log
# 4
# no log
# 5
# Iteration 5: Checkpoint saved to check_test_5.jb
# no log
# 6
# no log
# 7
# no log
# 8
# no log
# 9
# no log
# 10
# Iteration 10: Checkpoint saved to check_test_10.jb
# no log
# 11
# no log
# 12
# no log
# 13
# no log
# 14
# no log
# 15
# Iteration 15: Checkpoint saved to check_test_15.jb
# no log
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 6
#       1 mod_lin_sse = OneCompartmentModel(dep_vars= {'k':[ ObjectiveFunctionColumn('AGE_scale'),
#       2                                                 ObjectiveFunctionColumn('SEX')],
#       3                                            'vd':[ObjectiveFunctionColumn('WT_scale',)]},
#       4                                   loss_function=sum_of_squares_loss
#       5                                   )
# ----> 6 mod_lin_sse = mod_lin_sse.fit(scale_df)
#
# File /workspaces/miniconda/PK-Analysis/utils.py:367, in OneCompartmentModel.fit(self, data, parallel)
#     364 def fit(self, data, parallel = False):
#     365     # bounds = [(None, None) for i in range(len(self.dep_vars) + len(self.population_coeff))]
#     366     objective_function = partial(self._objective_function, parallel = parallel)
# --> 367     self.fit_result_ = optimize_with_checkpoint_joblib(objective_function,
#     368                                                        self.init_vals,
#     369                                                        n_checkpoint=5,
#     370                                                        checkpoint_filename='check_test.jb',
#     371                                                        args=(data,),
#     372                                                        bounds=self.bounds
#     373                                                        )
#     374     res_df = []
#     375     written_indep_var_rows = 0
#
# File /workspaces/miniconda/PK-Analysis/utils.py:646, in optimize_with_checkpoint_joblib(func, x0, n_checkpoint, checkpoint_filename, *args, **kwargs)
#     642         user_callback(xk)
#     644     kwargs['callback'] = combined_callback
# --> 646 result = minimize(func, x0, *args, **kwargs)
#     648 # Remove checkpoint file at end.
#     649 # try:
#     650 #    os.remove(checkpoint_filename)
#     651 # except:
#     652 #    pass
#     654 return result
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_minimize.py:731, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     728     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     729                              **options)
#     730 elif meth == 'l-bfgs-b':
# --> 731     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     732                            callback=callback, **options)
#     733 elif meth == 'tnc':
#     734     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     735                         **options)
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_lbfgsb_py.py:407, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     401 task_str = task.tobytes()
#     402 if task_str.startswith(b'FG'):
#     403     # The minimization routine wants f and g at the current x.
#     404     # Note that interruptions due to maxfun are postponed
#     405     # until the completion of the current minimization iteration.
#     406     # Overwrite f and g:
# --> 407     f, g = func_and_grad(x)
#     408 elif task_str.startswith(b'NEW_X'):
#     409     # new iteration
#     410     n_iterations += 1
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:344, in ScalarFunction.fun_and_grad(self, x)
#     342     self._update_x(x)
#     343 self._update_fun()
# --> 344 self._update_grad()
#     345 return self.f, self.g
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:306, in ScalarFunction._update_grad(self)
#     304 if self._orig_grad in FD_METHODS:
#     305     self._update_fun()
# --> 306 self.g = self._wrapped_grad(self.x, f0=self.f)
#     307 self.g_updated = True
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:47, in _wrapper_grad.<locals>.wrapped1(x, f0)
#      45 def wrapped1(x, f0=None):
#      46     ncalls[0] += 1
# ---> 47     return approx_derivative(
#      48         fun, x, f0=f0, **finite_diff_options
#      49     )
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:592, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     590     x1[i] += h[i]
#     591     dx = x1[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 592     df = fun(x1) - f0
#     593 elif method == '3-point' and use_one_sided[i]:
#     594     x1[i] += h[i]
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# File /opt/conda/envs/pySunODE/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:20, in _wrapper_fun.<locals>.wrapped(x)
#      16 ncalls[0] += 1
#      17 # Send a copy because the user may overwrite it.
#      18 # Overwriting results in undefined behaviour because
#      19 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 20 fx = fun(np.copy(x), *args)
#      21 # Make sure the function returns a true scalar
#      22 if not np.isscalar(fx):
#
# File /workspaces/miniconda/PK-Analysis/utils.py:358, in OneCompartmentModel._objective_function(self, params, data, parallel)
#     356 other_params = params[n_pop_coeff:]
#     357 _betas = self._populate_model_betas(other_params)
# --> 358 preds = np.concatenate(self._predict_parallel(data = data)) if parallel else self._predict_alt(data=data)
#     359 #residuals = data[self.conc_at_time_col] - preds
#     360 #sse = np.sum(residuals**2)
#     361 error = self.loss_function(data[self.conc_at_time_col], preds, **self.loss_params)
#
# File /workspaces/miniconda/PK-Analysis/utils.py:288, in OneCompartmentModel._predict_alt(self, data)
#     286 def _predict_alt(self, data):
#     287     predictions = []
# --> 288     for subject_data in self._subject_iterator(data):
#     289         subject_preds = self._predict_inner(subject_data)
#     290         predictions.extend(subject_preds)
#
# File /workspaces/miniconda/PK-Analysis/utils.py:231, in OneCompartmentModel._subject_iterator(self, data)
#     229 subject_data = data.loc[subject_filt, :].copy()
#     230 initial_conc = subject_data[conc_at_time_c].values[0]
# --> 231 subject_coeff = deepcopy(self.population_coeff)
#     232 #subject_coeff = deepcopy(population_coeff)
#     233 subject_coeff = {
#     234     obj.coeff_name: obj.optimization_history[-1] for obj in subject_coeff}
#
# File /opt/conda/envs/pySunODE/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /opt/conda/envs/pySunODE/lib/python3.12/copy.py:196, in _deepcopy_list(x, memo, deepcopy)
#     194 append = y.append
#     195 for a in x:
# --> 196     append(deepcopy(a, memo))
#     197 return y
#
# File /opt/conda/envs/pySunODE/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File /opt/conda/envs/pySunODE/lib/python3.12/copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File /opt/conda/envs/pySunODE/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /opt/conda/envs/pySunODE/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File /opt/conda/envs/pySunODE/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /opt/conda/envs/pySunODE/lib/python3.12/copy.py:196, in _deepcopy_list(x, memo, deepcopy)
#     194 append = y.append
#     195 for a in x:
# --> 196     append(deepcopy(a, memo))
#     197 return y
#
# File /opt/conda/envs/pySunODE/lib/python3.12/copy.py:143, in deepcopy(x, memo, _nil)
#     141 copier = getattr(x, "__deepcopy__", None)
#     142 if copier is not None:
# --> 143     y = copier(memo)
#     144 else:
#     145     reductor = dispatch_table.get(cls)
#
# KeyboardInterrupt:

# %%
mod_lin_sse.fit_result_
# Out:
# <function utils.one_compartment_model(t, y, k, Vd, dose)>

# %%
# Out:
# No checkpoint found, starting from initial guess.
# 1
# no log
# 2
# no log
# 3
# no log
# 4
# no log

# %%
mod.fit_result_summary_
# Out:
#    population_coeff model_coeff model_coeff_indep_var  log_coeff  \
# 0              True           k                  None  -0.981034
# 1              True          vd                  None   0.024289
# 2             False           k             AGE_scale  -0.212214
# 3             False           k                   SEX  -0.510118
# 4             False          vd              WT_scale   0.478995
#
#    log_coeff_history_final  coeff_estimates_equal     coeff
# 0                -0.981034                   True  0.374923
# 1                 0.024289                   True  1.024586
# 2                -0.212214                   True  0.808791
# 3                -0.510118                   True  0.600425
# 4                 0.478995                  False  1.614451

# %%
mod.betas
# Out:
# {'k': {'AGE_scale': ObjectiveFunctionBeta(column_name='AGE_scale', value=-0.21221418486812021, allometric_norm_value=None, model_method='linear', optimization_lower_bound=None, optimization_upper_bound=None),
#   'SEX': ObjectiveFunctionBeta(column_name='SEX', value=-0.5101181836714316, allometric_norm_value=None, model_method='linear', optimization_lower_bound=None, optimization_upper_bound=None)},
#  21.89529418387349,
#  8.25987968488812,
#  1.1748608471676787,
#  0.06298629274346963,
#  0.003379941638481424,
#  9.729690474290331e-06,
#  1.296319293343794e-07,
#  115.0,
#  71.47032291256306,
#  44.41242139716043,
#  17.17497362028827,
#  6.640465736658537,
#  0.9925757435766975,
#  0.05731358744349929,
#  0.003309253016116753,
#  1.1167910235865255e-05,
#  6.339442191964028e-08,
#  149.0,
#  105.93500481352152,
#  53.56783836474869,
#  27.082118741705813,
#  6.930314632689308,
#  0.8959191687377613,
#  0.11593813241000864,
#  0.0019389172981126705,
#  3.254979544174067e-05,
#  86.19999694824219,
#  67.69447989005658,
#  53.15325114776192,
#  32.77368889589492,
#  20.228665510783216,
#  7.696319874265445,
#  2.928395272897456,
#  0.42409173876828016,
#  0.02338787824856292,
#  0.001288820213398404,
#  3.9613370455372765e-06,
#  3.57066010119965e-08,
#  171.0,
#  110.7620849357595,
#  46.51694500666877,
#  19.53061667757412,
#  3.442978944091161,
#  0.25483280157047306,
#  0.018861017658044266,
#  0.00010318332938155448,
#  6.858383966180321e-07,
#  87.0999984741211,
#  55.16971744776023,
#  34.93692130041877,
#  14.032307905575127,
#  5.634551604544074,
#  0.908545726936028,
#  0.058827860101039964,
#  0.003808609646925765,
#  1.5939081642110164e-05,
#  1.5146879265855417e-07,
#  127.0,
#  78.35647112354965,
#  29.854516157516223,
#  11.371644669470065,
#  ...]

# %%
objective_func_arbit_linear = partial(arbitrary_objective_function,
                               dep_vars = {'k':[ ObjectiveFunctionColumn('AGE_scale'),
                                                ObjectiveFunctionColumn('SEX')],
                                           'vd':[ObjectiveFunctionColumn('WT_scale',)]}
                               )


result_arbit_lin = optimize_with_checkpoint_joblib(objective_func_arbit_linear, initial_guess, n_checkpoint=5, checkpoint_filename='check_args_arbit_lin.jb', args=(
    # Bounds added to prevent negative values
    scale_df,), bounds=[(None, None), (None, None), (None, None), (None, None), (None, None),])

# %%
np.exp(result_arbit_allo['x'])
# Out:
# array([0.37492311, 1.02458642, 0.80879145, 0.60042461, 1.61445107])

# %%
np.exp(result_arbit_lin['x'])
# Out:
# array([0.58163838, 2.20294476, 0.94509567, 0.86590837, 1.03079841])

# %%
np.exp(result_arbit['x'])
# Out:
# array([0.37492311, 1.02458642, 0.80879145, 0.60042461, 1.61445107])

# %%
np.exp(result_arbit['x'])
# Out:
# array([0.58163838, 2.20294476, 0.94509567, 0.86590837, 1.03079841])

# %%
from utils import objective_function__mgkg_age
objective_func = partial(objective_function__mgkg_age, mgkg_c = 'MGKG_scale', age_c = 'AGE_scale')

# %%
#scale_df = scale_df.reset_index()
initial_guess = [np.log(0.6), np.log(2.0), 0, 0, 0, 0]  # Initial guesses for k_pop and Vd_pop, k_beta_age, k_beta_mgkg, Vd_beta_age, Vd_beta_mgkg
result = optimize_with_checkpoint_joblib(objective_func, initial_guess, n_checkpoint=5, checkpoint_filename='check_args.jb', args=(
    # Bounds added to prevent negative values
    scale_df,), bounds=[(None, None), (None, None), (None, None), (None, None), (None, None), (None, None)])
# result = minimize(objective_function, initial_guess, args=(work_df,), bounds=[(1e-6,None),(1e-6,None)])

# %%
result

# %%
np.exp(result['x'])

# %%
def generate_predictions__mgkg_age(optimized_result, 
                                   df, subject_id_c='SUBJID', dose_c='DOSR',
                                   time_c='TIME', conc_at_time_c='DV',
                                   mgkg_c='MGKG', age_c='AGE'):
    predictions = {}
    k_pop, Vd_pop, k_beta_age, k_beta_mgkg, Vd_beta_age, Vd_beta_mgkg = optimized_result.x
    data = df.copy()
    for subject in data[subject_id_c].unique(): # Loop through each subject in the dataset
        subject_filt =  data[subject_id_c] == subject
        subject_data = data.loc[subject_filt, :].copy()
        
        mgkg = subject_data[mgkg_c].values[0]  # Extract dose information for the subject
        age = subject_data[age_c].values[0]
          # Get data for the current subject
        initial_conc = subject_data[conc_at_time_c].values[0]  # Get the initial concentration
        with np.errstate(over='ignore'):
            k_i = np.exp(k_pop + (k_beta_age * age) + (k_beta_mgkg * mgkg))
            Vd_i = np.exp(Vd_pop + (Vd_beta_age * age) + (Vd_beta_mgkg * mgkg))
        # Solve the differential equation for the current subject
        sol = solve_ivp(one_compartment_model, [subject_data[time_c].min(), subject_data[time_c].max()], [initial_conc], 
                        t_eval=subject_data[time_c], args=(k_i, Vd_i, mgkg))
        predictions[subject] = sol
    return predictions

# %%
from utils import generate_ivp_predictions, stack_ivp_predictions, merge_ivp_predictions
preds = generate_predictions__mgkg_age(result, scale_df)
preds_plot_df = merge_ivp_predictions(scale_df, preds)

# %%
from utils import generate_ivp_predictions, stack_ivp_predictions, merge_ivp_predictions
predictions = generate_ivp_predictions(result_0, scale_df)

# %%
merge_df_0 = merge_ivp_predictions(preds_plot_df, predictions)
merge_df_0.head()
merge_df = merge_df_0.copy()

# %%
merge_df['PRED_DV_diff'] = (merge_df['Pred_DV'] - merge_df['DV'])
merge_df['PRED_DV_diff_sign'] = np.sign(merge_df['PRED_DV_diff']+1e-6)
merge_df['PRED_DV_diff_log'] = np.log((np.abs(merge_df['PRED_DV_diff']) + 1e-6)) * merge_df['PRED_DV_diff_sign']  
merge_df['PRED_DV_diff_%'] = 100 * ((merge_df['Pred_DV'] - merge_df['DV'])/ ((merge_df['Pred_DV'] + merge_df['DV']) / 2))
merge_df['log_PRED_DV_diff_%'] = np.log(np.abs(merge_df['PRED_DV_diff_%']) + 1e-6)

# %%
merge_df

# %%
plot_subject_levels(merge_df, x = 'TIME', y = 'PRED_DV_diff')

# %%
plot_subject_levels(merge_df, x = 'TIME', y = 'PRED_DV_diff_log')

# %%
import matplotlib.pyplot as plt
subject_id = 5
plot_df = scale_df.loc[scale_df['SUBJID'] == subject_id, :]
plt.plot(predictions[subject_id].t, predictions[subject_id].y[0], label = 'PRED')
plt.plot(predictions[subject_id].t, plot_df['DV'].values, label = 'TRUE')
plt.legend()

# %%
import matplotlib.pyplot as plt
subject_id = 5
plot_df = preds_plot_df.loc[preds_plot_df['SUBJID'] == subject_id, :]
plt.plot(preds[subject_id].t, preds[subject_id].y[0], label = 'PRED')
plt.plot(preds[subject_id].t, plot_df['DV'].values, label = 'TRUE')
plt.legend()
